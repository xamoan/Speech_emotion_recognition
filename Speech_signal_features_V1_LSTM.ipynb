# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Librerie

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
import os
import librosa
import IPython.display as ipd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa

from sklearn.preprocessing import  OneHotEncoder, StandardScaler
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, classification_report
from keras.models import Sequential, Model
from keras.layers import Dense, Input, Conv2D, MaxPool2D, Dropout, Flatten, Conv1D, MaxPool1D, BatchNormalization
import tensorflow

# %% [markdown]
# # Preparazione dei dati

# %% [markdown]
# Importazione del dataset "speech_signal_features_V1s". Questo dataset contiene le features estratte dai seguenti dataset: Ravdess, SAVEE, TESS, CREMA-D. Le features in questione sono:
# - Zero crossing rate
# - Root mean square error
# - MFFCs

# %%
Features_df = pd.read_csv('/content/drive/MyDrive/speech_signal_features_V1.csv')
Features_df
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.331543  0.471680  0.564941  0.452148  0.374512  0.296875  0.265137
# 1      0.251953  0.373535  0.494141  0.501465  0.482910  0.482422  0.476562
# 2      0.299805  0.419922  0.525879  0.459473  0.378418  0.326172  0.282227
# 3      0.261719  0.388672  0.513184  0.509277  0.500977  0.496582  0.486816
# 4      0.400879  0.591309  0.783203  0.777832  0.771973  0.777832  0.771973
# ...         ...       ...       ...       ...       ...       ...       ...
# 48643  0.026855  0.044434  0.062012  0.060547  0.064453  0.059570  0.074219
# 48644  0.023926  0.035156  0.040527  0.035645  0.032715  0.029297  0.032715
# 48645  0.025879  0.053711  0.087402  0.104004  0.103027  0.083008  0.062012
# 48646  0.022461  0.034668  0.041992  0.038086  0.038086  0.034668  0.036133
# 48647  0.022461  0.034668  0.041992  0.038086  0.038086  0.034668  0.036133
#
#               7         8         9  ...      2367      2368      2369  \
# 0      0.256348  0.252441  0.251953  ... -1.517647 -1.716411 -1.599245
# 1      0.463379  0.469238  0.466309  ... -1.614816 -3.268710 -2.181269
# 2      0.260254  0.258789  0.253906  ...  0.518934  0.839123  1.308966
# 3      0.487793  0.479980  0.491699  ... -1.774671 -1.750296  1.640066
# 4      0.775391  0.758789  0.580078  ...  2.585885  2.746578  2.223155
# ...         ...       ...       ...  ...       ...       ...       ...
# 48643  0.113281  0.133301  0.141113  ... -2.997387 -2.857280 -0.232463
# 48644  0.048340  0.125488  0.214844  ... -5.741305 -4.147367 -7.531296
# 48645  0.067383  0.142090  0.231445  ... -5.524943 -8.097495 -2.270405
# 48646  0.044434  0.117676  0.207031  ... -4.208822  3.741516 -2.212307
# 48647  0.044434  0.115723  0.202148  ... -5.233647  2.385797 -0.603511
#
#            2370      2371       2372      2373      2374      2375  Emotions
# 0     -1.234544 -0.693115  -0.038821  0.675410  1.405862  2.112551  surprise
# 1     -4.098365 -5.258773  -5.286760 -6.192348 -1.996428  2.875362  surprise
# 2      1.855113  2.404974   2.896071  3.282975  3.541090  3.666844  surprise
# 3      1.664761  0.510230   1.624107  0.165312 -0.924339 -2.566185  surprise
# 4      0.986784 -0.730885  -2.531058 -4.002847 -4.849191 -4.929410   neutral
# ...         ...       ...        ...       ...       ...       ...       ...
# 48643 -1.449387  3.244326   3.075974  5.609814  8.831363 -1.798762     angry
# 48644 -3.492054 -2.512286 -11.724421 -7.290385  1.041336  1.246793     happy
# 48645 -1.362404 -6.644628  -5.624853 -5.777763 -5.503017 -2.788878     happy
# 48646  1.554494 -3.257353 -17.360359 -1.698290  6.971038 -4.712044     happy
# 48647  0.293539 -3.992488 -14.444147 -2.231435  5.424299 -4.705208     happy
#
# [48648 rows x 2377 columns]

# %% [markdown]
# Di seguito è riportato il controllo relativo ai valori NaN all'interno del dataset. Nel caso fossero presenti sono sostituiti con valori nulli

# %%
Features_df.isna().values.any()
# Out:
# True

# %%
Features_df=Features_df.fillna(0)
np.sum(Features_df.isna())
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 2372        0
# 2373        0
# 2374        0
# 2375        0
# Emotions    0
# Length: 2377, dtype: int64

# %%
Features_df.isna().values.any()
# Out:
# False

# %% [markdown]
# A questo punto vengono creati i set di training e di testing

# %%
X = Features_df.iloc[: ,:-1].values
Y = Features_df['Emotions'].values

encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray().astype(int)
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state = 3)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (38918, 2376)
# (38918, 7)
# (9730, 2376)
# (9730, 7)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((38918, 2376), (38918, 7), (9730, 2376), (9730, 7))

# %% [markdown]
# Dato che questo tipo di architetture prende in input una sequenza in questo caso non serve aggiungere una dimensione fittizia ai nostri dati

# %% [markdown]
# #Architetture LSTM

# %%
from keras import layers, optimizers
def build_model(input_shape):
    model = tensorflow.keras.Sequential()
    model.add(layers.LSTM(128, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(layers.LSTM(128,return_sequences=True))
    model.add(Dropout(0.2))
    model.add(layers.LSTM(128,return_sequences=True))
    model.add(Dropout(0.2))
    model.add(layers.LSTM(128))
    model.add(Dropout(0.2))
    model.add(layers.Dense(7, activation='softmax'))

    return model

# %%
model = build_model((x_train.shape[1],1))

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 2376, 128)         66560
#
#  dropout (Dropout)           (None, 2376, 128)         0
#
#  lstm_1 (LSTM)               (None, 2376, 128)         131584
#
#  dropout_1 (Dropout)         (None, 2376, 128)         0
#
#  lstm_2 (LSTM)               (None, 2376, 128)         131584
#
#  dropout_2 (Dropout)         (None, 2376, 128)         0
#
#  lstm_3 (LSTM)               (None, 128)               131584
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 7)                 903
#
# =================================================================
# Total params: 462215 (1.76 MB)
# Trainable params: 462215 (1.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
hist=model.fit(x_train, y_train,
            epochs=100,
            validation_data=(x_test, y_test),batch_size=64,
            verbose=1)
# Out:
# Epoch 1/100
# 609/609 [==============================] - 252s 414ms/step - loss: 1.9057 - accuracy: 0.1586 - val_loss: 1.9067 - val_accuracy: 0.1575
# Epoch 2/100
# 609/609 [==============================] - 233s 382ms/step - loss: 1.9056 - accuracy: 0.1578 - val_loss: 1.9056 - val_accuracy: 0.1523
# Epoch 3/100
# 609/609 [==============================] - 252s 414ms/step - loss: 1.9057 - accuracy: 0.1555 - val_loss: 1.9056 - val_accuracy: 0.1551
# Epoch 4/100
# 609/609 [==============================] - 253s 416ms/step - loss: 1.9053 - accuracy: 0.1561 - val_loss: 1.9064 - val_accuracy: 0.1588
# Epoch 5/100
# 609/609 [==============================] - 253s 415ms/step - loss: 1.9054 - accuracy: 0.1563 - val_loss: 1.9058 - val_accuracy: 0.1551
# Epoch 6/100
# 609/609 [==============================] - 254s 417ms/step - loss: 1.9053 - accuracy: 0.1593 - val_loss: 1.9053 - val_accuracy: 0.1588
# Epoch 7/100
# 609/609 [==============================] - 252s 414ms/step - loss: 1.9053 - accuracy: 0.1549 - val_loss: 1.9062 - val_accuracy: 0.1523
# Epoch 8/100
# 609/609 [==============================] - 253s 415ms/step - loss: 1.9052 - accuracy: 0.1571 - val_loss: 1.9055 - val_accuracy: 0.1523
# Epoch 9/100
# 609/609 [==============================] - 254s 416ms/step - loss: 1.9051 - accuracy: 0.1565 - val_loss: 1.9054 - val_accuracy: 0.1606
# Epoch 10/100
# 609/609 [==============================] - 255s 419ms/step - loss: 1.8979 - accuracy: 0.1741 - val_loss: 1.8878 - val_accuracy: 0.1884
# Epoch 11/100
# 609/609 [==============================] - 256s 420ms/step - loss: 1.8840 - accuracy: 0.1970 - val_loss: 1.8793 - val_accuracy: 0.2050
# Epoch 12/100
# 609/609 [==============================] - 254s 417ms/step - loss: 1.8805 - accuracy: 0.2066 - val_loss: 1.8767 - val_accuracy: 0.2083
# Epoch 13/100
# 609/609 [==============================] - 257s 421ms/step - loss: 1.8775 - accuracy: 0.2096 - val_loss: 1.8784 - val_accuracy: 0.2117
# Epoch 14/100
# 609/609 [==============================] - 257s 422ms/step - loss: 1.8935 - accuracy: 0.1812 - val_loss: 1.8960 - val_accuracy: 0.1843
# Epoch 15/100
# 609/609 [==============================] - 259s 426ms/step - loss: 1.8893 - accuracy: 0.1931 - val_loss: 1.8841 - val_accuracy: 0.1976
# Epoch 16/100
# 609/609 [==============================] - 260s 427ms/step - loss: 1.8752 - accuracy: 0.2076 - val_loss: 1.8787 - val_accuracy: 0.1819
# Epoch 17/100
# 609/609 [==============================] - 261s 429ms/step - loss: 1.8576 - accuracy: 0.2207 - val_loss: 1.8502 - val_accuracy: 0.2313
# Epoch 18/100
# 609/609 [==============================] - 243s 399ms/step - loss: 1.8242 - accuracy: 0.2369 - val_loss: 1.7971 - val_accuracy: 0.2514
# Epoch 19/100
# 609/609 [==============================] - 262s 431ms/step - loss: 1.7923 - accuracy: 0.2518 - val_loss: 1.7765 - val_accuracy: 0.2566
# Epoch 20/100
# 609/609 [==============================] - 260s 426ms/step - loss: 1.8782 - accuracy: 0.1926 - val_loss: 1.8693 - val_accuracy: 0.1993
# Epoch 21/100
# 609/609 [==============================] - 240s 394ms/step - loss: 1.8780 - accuracy: 0.1920 - val_loss: 1.8948 - val_accuracy: 0.1853
# Epoch 22/100
# 609/609 [==============================] - 260s 427ms/step - loss: 1.8613 - accuracy: 0.2048 - val_loss: 1.8549 - val_accuracy: 0.2081
# Epoch 23/100
# 609/609 [==============================] - 261s 428ms/step - loss: 1.8354 - accuracy: 0.2241 - val_loss: 1.7200 - val_accuracy: 0.3047
# Epoch 24/100
# 609/609 [==============================] - 262s 431ms/step - loss: 1.7837 - accuracy: 0.2632 - val_loss: 1.6667 - val_accuracy: 0.3171
# Epoch 25/100
# 609/609 [==============================] - 263s 432ms/step - loss: 1.6999 - accuracy: 0.3062 - val_loss: 1.7073 - val_accuracy: 0.2923
# Epoch 26/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.6611 - accuracy: 0.3294 - val_loss: 1.6368 - val_accuracy: 0.3340
# Epoch 27/100
# 609/609 [==============================] - 243s 399ms/step - loss: 1.6415 - accuracy: 0.3394 - val_loss: 1.6259 - val_accuracy: 0.3485
# Epoch 28/100
# 609/609 [==============================] - 262s 431ms/step - loss: 1.6454 - accuracy: 0.3397 - val_loss: 1.5999 - val_accuracy: 0.3557
# Epoch 29/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.5820 - accuracy: 0.3658 - val_loss: 1.5427 - val_accuracy: 0.3867
# Epoch 30/100
# 609/609 [==============================] - 243s 399ms/step - loss: 1.5433 - accuracy: 0.3769 - val_loss: 1.4966 - val_accuracy: 0.4024
# Epoch 31/100
# 609/609 [==============================] - 262s 431ms/step - loss: 1.5023 - accuracy: 0.3937 - val_loss: 1.5277 - val_accuracy: 0.3827
# Epoch 32/100
# 609/609 [==============================] - 263s 432ms/step - loss: 1.4710 - accuracy: 0.4056 - val_loss: 1.4442 - val_accuracy: 0.4217
# Epoch 33/100
# 609/609 [==============================] - 243s 399ms/step - loss: 1.4247 - accuracy: 0.4239 - val_loss: 1.4392 - val_accuracy: 0.4047
# Epoch 34/100
# 609/609 [==============================] - 262s 431ms/step - loss: 1.5293 - accuracy: 0.3815 - val_loss: 1.5694 - val_accuracy: 0.3701
# Epoch 35/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.4352 - accuracy: 0.4218 - val_loss: 1.5113 - val_accuracy: 0.3968
# Epoch 36/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.4066 - accuracy: 0.4354 - val_loss: 1.4232 - val_accuracy: 0.4254
# Epoch 37/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.3733 - accuracy: 0.4499 - val_loss: 1.4009 - val_accuracy: 0.4355
# Epoch 38/100
# 609/609 [==============================] - 263s 432ms/step - loss: 1.3482 - accuracy: 0.4589 - val_loss: 1.3560 - val_accuracy: 0.4565
# Epoch 39/100
# 609/609 [==============================] - 243s 400ms/step - loss: 1.3524 - accuracy: 0.4624 - val_loss: 1.4058 - val_accuracy: 0.4386
# Epoch 40/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.3172 - accuracy: 0.4729 - val_loss: 1.3027 - val_accuracy: 0.4705
# Epoch 41/100
# 609/609 [==============================] - 263s 432ms/step - loss: 1.3811 - accuracy: 0.4484 - val_loss: 1.3362 - val_accuracy: 0.4627
# Epoch 42/100
# 609/609 [==============================] - 263s 432ms/step - loss: 1.3019 - accuracy: 0.4810 - val_loss: 1.2881 - val_accuracy: 0.4794
# Epoch 43/100
# 609/609 [==============================] - 263s 432ms/step - loss: 1.2847 - accuracy: 0.4910 - val_loss: 1.2696 - val_accuracy: 0.4930
# Epoch 44/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.2715 - accuracy: 0.4963 - val_loss: 1.2957 - val_accuracy: 0.4823
# Epoch 45/100
# 609/609 [==============================] - 263s 432ms/step - loss: 1.2588 - accuracy: 0.4998 - val_loss: 1.3448 - val_accuracy: 0.4690
# Epoch 46/100
# 609/609 [==============================] - 263s 432ms/step - loss: 1.2491 - accuracy: 0.5048 - val_loss: 1.2237 - val_accuracy: 0.5153
# Epoch 47/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.2319 - accuracy: 0.5107 - val_loss: 1.2586 - val_accuracy: 0.4983
# Epoch 48/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.2143 - accuracy: 0.5193 - val_loss: 1.2744 - val_accuracy: 0.4978
# Epoch 49/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.2012 - accuracy: 0.5253 - val_loss: 1.2274 - val_accuracy: 0.5112
# Epoch 50/100
# 609/609 [==============================] - 262s 431ms/step - loss: 1.1870 - accuracy: 0.5308 - val_loss: 1.1961 - val_accuracy: 0.5274
# Epoch 51/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.1762 - accuracy: 0.5336 - val_loss: 1.2205 - val_accuracy: 0.5197
# Epoch 52/100
# 609/609 [==============================] - 263s 432ms/step - loss: 1.1604 - accuracy: 0.5413 - val_loss: 1.1685 - val_accuracy: 0.5429
# Epoch 53/100
# 609/609 [==============================] - 243s 399ms/step - loss: 1.1392 - accuracy: 0.5506 - val_loss: 1.1728 - val_accuracy: 0.5413
# Epoch 54/100
# 609/609 [==============================] - 262s 431ms/step - loss: 1.1281 - accuracy: 0.5556 - val_loss: 1.1404 - val_accuracy: 0.5494
# Epoch 55/100
# 609/609 [==============================] - 262s 431ms/step - loss: 1.1141 - accuracy: 0.5609 - val_loss: 1.1425 - val_accuracy: 0.5495
# Epoch 56/100
# 609/609 [==============================] - 243s 399ms/step - loss: 1.1049 - accuracy: 0.5635 - val_loss: 1.1582 - val_accuracy: 0.5347
# Epoch 57/100
# 609/609 [==============================] - 262s 431ms/step - loss: 1.0927 - accuracy: 0.5707 - val_loss: 1.1224 - val_accuracy: 0.5583
# Epoch 58/100
# 609/609 [==============================] - 262s 431ms/step - loss: 1.0787 - accuracy: 0.5757 - val_loss: 1.0782 - val_accuracy: 0.5826
# Epoch 59/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.0741 - accuracy: 0.5765 - val_loss: 1.0867 - val_accuracy: 0.5723
# Epoch 60/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.0651 - accuracy: 0.5832 - val_loss: 1.0888 - val_accuracy: 0.5696
# Epoch 61/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.1667 - accuracy: 0.5354 - val_loss: 1.1423 - val_accuracy: 0.5508
# Epoch 62/100
# 609/609 [==============================] - 262s 431ms/step - loss: 1.0459 - accuracy: 0.5890 - val_loss: 1.0899 - val_accuracy: 0.5659
# Epoch 63/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.0303 - accuracy: 0.5944 - val_loss: 1.0683 - val_accuracy: 0.5795
# Epoch 64/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.0141 - accuracy: 0.5994 - val_loss: 1.1351 - val_accuracy: 0.5662
# Epoch 65/100
# 609/609 [==============================] - 263s 432ms/step - loss: 1.0097 - accuracy: 0.6030 - val_loss: 1.0608 - val_accuracy: 0.5873
# Epoch 66/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.0099 - accuracy: 0.6044 - val_loss: 1.0433 - val_accuracy: 0.5882
# Epoch 67/100
# 609/609 [==============================] - 263s 431ms/step - loss: 1.0059 - accuracy: 0.6056 - val_loss: 1.0445 - val_accuracy: 0.5872
# Epoch 68/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.9819 - accuracy: 0.6136 - val_loss: 1.0192 - val_accuracy: 0.6050
# Epoch 69/100
# 609/609 [==============================] - 262s 431ms/step - loss: 0.9733 - accuracy: 0.6198 - val_loss: 1.0360 - val_accuracy: 0.5941
# Epoch 70/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.9634 - accuracy: 0.6256 - val_loss: 1.0256 - val_accuracy: 0.5982
# Epoch 71/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.9516 - accuracy: 0.6318 - val_loss: 1.0077 - val_accuracy: 0.6039
# Epoch 72/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.9376 - accuracy: 0.6367 - val_loss: 1.0404 - val_accuracy: 0.6005
# Epoch 73/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.9638 - accuracy: 0.6285 - val_loss: 1.0022 - val_accuracy: 0.6106
# Epoch 74/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.9253 - accuracy: 0.6434 - val_loss: 0.9742 - val_accuracy: 0.6215
# Epoch 75/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.9171 - accuracy: 0.6451 - val_loss: 0.9896 - val_accuracy: 0.6162
# Epoch 76/100
# 609/609 [==============================] - 243s 399ms/step - loss: 0.9063 - accuracy: 0.6496 - val_loss: 0.9941 - val_accuracy: 0.6107
# Epoch 77/100
# 609/609 [==============================] - 262s 430ms/step - loss: 0.8992 - accuracy: 0.6512 - val_loss: 0.9597 - val_accuracy: 0.6295
# Epoch 78/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.8956 - accuracy: 0.6541 - val_loss: 0.9747 - val_accuracy: 0.6212
# Epoch 79/100
# 609/609 [==============================] - 269s 441ms/step - loss: 0.8836 - accuracy: 0.6591 - val_loss: 1.0044 - val_accuracy: 0.6133
# Epoch 80/100
# 609/609 [==============================] - 263s 432ms/step - loss: 0.8753 - accuracy: 0.6633 - val_loss: 0.9783 - val_accuracy: 0.6240
# Epoch 81/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.8553 - accuracy: 0.6710 - val_loss: 0.9314 - val_accuracy: 0.6412
# Epoch 82/100
# 609/609 [==============================] - 262s 431ms/step - loss: 0.8495 - accuracy: 0.6760 - val_loss: 0.9695 - val_accuracy: 0.6319
# Epoch 83/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.8441 - accuracy: 0.6770 - val_loss: 0.9257 - val_accuracy: 0.6437
# Epoch 84/100
# 609/609 [==============================] - 243s 400ms/step - loss: 0.8344 - accuracy: 0.6788 - val_loss: 0.9125 - val_accuracy: 0.6475
# Epoch 85/100
# 609/609 [==============================] - 262s 431ms/step - loss: 0.8306 - accuracy: 0.6797 - val_loss: 0.9240 - val_accuracy: 0.6438
# Epoch 86/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.8168 - accuracy: 0.6866 - val_loss: 0.9574 - val_accuracy: 0.6342
# Epoch 87/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.8165 - accuracy: 0.6887 - val_loss: 0.9583 - val_accuracy: 0.6318
# Epoch 88/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.7937 - accuracy: 0.6946 - val_loss: 0.9248 - val_accuracy: 0.6507
# Epoch 89/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.7900 - accuracy: 0.6970 - val_loss: 0.9191 - val_accuracy: 0.6538
# Epoch 90/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.7830 - accuracy: 0.7023 - val_loss: 0.8885 - val_accuracy: 0.6688
# Epoch 91/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.7765 - accuracy: 0.7030 - val_loss: 0.8923 - val_accuracy: 0.6625
# Epoch 92/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.7710 - accuracy: 0.7069 - val_loss: 0.9249 - val_accuracy: 0.6525
# Epoch 93/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.7570 - accuracy: 0.7112 - val_loss: 0.8854 - val_accuracy: 0.6652
# Epoch 94/100
# 609/609 [==============================] - 262s 431ms/step - loss: 0.7498 - accuracy: 0.7154 - val_loss: 0.9132 - val_accuracy: 0.6579
# Epoch 95/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.7400 - accuracy: 0.7173 - val_loss: 0.9155 - val_accuracy: 0.6561
# Epoch 96/100
# 609/609 [==============================] - 262s 431ms/step - loss: 0.7317 - accuracy: 0.7219 - val_loss: 0.9236 - val_accuracy: 0.6554
# Epoch 97/100
# 609/609 [==============================] - 265s 435ms/step - loss: 0.7339 - accuracy: 0.7210 - val_loss: 0.9137 - val_accuracy: 0.6587
# Epoch 98/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.7232 - accuracy: 0.7290 - val_loss: 0.8747 - val_accuracy: 0.6741
# Epoch 99/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.7134 - accuracy: 0.7283 - val_loss: 0.8724 - val_accuracy: 0.6760
# Epoch 100/100
# 609/609 [==============================] - 263s 431ms/step - loss: 0.7004 - accuracy: 0.7369 - val_loss: 0.9165 - val_accuracy: 0.6675

# %%
print("Accuratezza del modello sulla base dei dati di test: " , model.evaluate(x_test,y_test)[1]*100 , "%")
epochs = [i for i in range(100)]
fig , ax = plt.subplots(1,2)
train_acc = hist.history['accuracy']
train_loss = hist.history['loss']
test_acc = hist.history['val_accuracy']
test_loss = hist.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 305/305 [==============================] - 36s 117ms/step - loss: 0.9165 - accuracy: 0.6675
# Accuratezza del modello sulla base dei dati di test:  66.75231456756592 %

# %% [markdown]
# # Evaluation model

# %%
# predicting on test data.
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)
# Out:
# 305/305 [==============================] - 35s 112ms/step

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0            angry         angry
# 1              sad           sad
# 2          neutral       neutral
# 3              sad           sad
# 4            angry         angry
# 5             fear           sad
# 6              sad          fear
# 7          neutral       neutral
# 8          disgust         angry
# 9              sad           sad

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.72      0.77      0.75      1509
#      disgust       0.61      0.60      0.61      1482
#         fear       0.69      0.53      0.60      1539
#        happy       0.61      0.67      0.64      1545
#      neutral       0.65      0.77      0.70      1532
#          sad       0.66      0.61      0.63      1597
#     surprise       0.89      0.82      0.85       526
#
#     accuracy                           0.67      9730
#    macro avg       0.69      0.68      0.68      9730
# weighted avg       0.67      0.67      0.67      9730
